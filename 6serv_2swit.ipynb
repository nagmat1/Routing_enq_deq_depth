# %%
# 5 Servers and 1 switch example 
#Import Fablib library
from fabrictestbed_extensions.fablib.fablib import FablibManager as fablib_manager
fablib = fablib_manager()

# %%
slice = fablib.new_slice(name="Server11")

# %%
site1='UCSD'
print (f'The selected sites are {site1}')
# Out:
# The selected sites are UCSD

# %%
server1 = slice.add_node(name="server1", 
                      site=site1, 
                      cores=8, 
                      ram=16, 
                      disk=500, 
                      image='default_ubuntu_20')

server2 = slice.add_node(name="server2", 
                      site=site1, 
                      cores=8, 
                      ram=16, 
                      disk=500, 
                      image='default_ubuntu_20')

user1 = slice.add_node(name="user1", 
                      site=site1, 
                      cores=8, 
                      ram=16, 
                      disk=500, 
                      image='default_ubuntu_20')

user2 = slice.add_node(name="user2", 
                      site=site1, 
                      cores=8, 
                      ram=16, 
                      disk=500, 
                      image='default_ubuntu_20')

cont = slice.add_node(name="cont", 
                      site=site1, 
                      cores=8, 
                      ram=16, 
                      disk=500, 
                      image='default_ubuntu_20')

# %%
#2
server3 = slice.add_node(name="server3", 
                      site=site1, 
                      cores=8, 
                      ram=16, 
                      disk=500, 
                      image='default_ubuntu_20')

# %%
server1_iface = server1.add_component(model='NIC_Basic').get_interfaces()[0]
server2_iface = server2.add_component(model='NIC_Basic').get_interfaces()[0]
user1_iface = user1.add_component(model='NIC_Basic').get_interfaces()[0]
user2_iface = user2.add_component(model='NIC_Basic').get_interfaces()[0]
cont_iface = cont.add_component(model='NIC_Basic').get_interfaces()[0]

# %%
#2
server1_iface2 = server1.add_component(model='NIC_Basic', name='s1_net2_nic').get_interfaces()[0]
server3_iface = server3.add_component(model='NIC_Basic').get_interfaces()[0]

# %%
# Add a node
switch = slice.add_node(name="switch", 
                      site=site1, 
                      cores=32, 
                      ram=16, 
                      disk=40, 
                      image='default_ubuntu_20')

# %%
#2 Switch2  
switch2 = slice.add_node(name="switch2", 
                      site=site1, 
                      cores=32, 
                      ram=16, 
                      disk=40, 
                      image='default_ubuntu_20')

# %%
switch_iface1 = switch.add_component(model='NIC_Basic', name='net1_nic').get_interfaces()[0]
switch_iface2 = switch.add_component(model='NIC_Basic', name='net2_nic').get_interfaces()[0]
switch_iface3 = switch.add_component(model='NIC_Basic', name='net3_nic').get_interfaces()[0]
switch_iface4 = switch.add_component(model='NIC_Basic', name='net4_nic').get_interfaces()[0]
switch_iface5 = switch.add_component(model='NIC_Basic', name='net5_nic').get_interfaces()[0]

# %%
#2
switch2_iface1 = switch2.add_component(model='NIC_Basic', name='sw2_net1_nic').get_interfaces()[0]
switch2_iface2 = switch2.add_component(model='NIC_Basic', name='sw2_net2_nic').get_interfaces()[0]

# %%
net1 = slice.add_l2network(name='net1', interfaces=[server1_iface, switch_iface1])
net2 = slice.add_l2network(name='net2', interfaces=[switch_iface2, server2_iface])
net3 = slice.add_l2network(name='net3', interfaces=[user1_iface, switch_iface3])
net4 = slice.add_l2network(name='net4', interfaces=[switch_iface4, user2_iface])
net5 = slice.add_l2network(name='net5', interfaces=[switch_iface5, cont_iface])

# %%
#2
net6 = slice.add_l2network(name='net6', interfaces=[server1_iface2, switch2_iface1])
net7 = slice.add_l2network(name='net7', interfaces=[switch2_iface2, server3_iface])

# %%
#Submit Slice Request
slice.submit();
# Out:
# Retry: 16, Time: 876 sec
# <style type="text/css">
# #T_4704e tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_4704e tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_4704e caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_4704e_row0_col0, #T_4704e_row0_col1, #T_4704e_row1_col0, #T_4704e_row1_col1, #T_4704e_row2_col0, #T_4704e_row2_col1, #T_4704e_row3_col0, #T_4704e_row3_col1, #T_4704e_row4_col0, #T_4704e_row4_col1, #T_4704e_row5_col0 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: ;
# }
# #T_4704e_row5_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: #c3ffc4;
# }
# </style>
# <table id="T_4704e">
#   <caption>Slice</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_4704e_row0_col0" class="data row0 col0" >ID</td>
#       <td id="T_4704e_row0_col1" class="data row0 col1" >232cc252-ed8f-441d-9bae-28e5d62ec0c2</td>
#     </tr>
#     <tr>
#       <td id="T_4704e_row1_col0" class="data row1 col0" >Name</td>
#       <td id="T_4704e_row1_col1" class="data row1 col1" >Server11</td>
#     </tr>
#     <tr>
#       <td id="T_4704e_row2_col0" class="data row2 col0" >Lease Expiration (UTC)</td>
#       <td id="T_4704e_row2_col1" class="data row2 col1" >2024-02-01 18:28:25 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_4704e_row3_col0" class="data row3 col0" >Lease Start (UTC)</td>
#       <td id="T_4704e_row3_col1" class="data row3 col1" >2024-01-31 18:28:26 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_4704e_row4_col0" class="data row4 col0" >Project ID</td>
#       <td id="T_4704e_row4_col1" class="data row4 col1" >527832fc-c273-4254-b988-16e5c2923bf9</td>
#     </tr>
#     <tr>
#       <td id="T_4704e_row5_col0" class="data row5 col0" >State</td>
#       <td id="T_4704e_row5_col1" class="data row5 col1" >StableOK</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_bbbfd caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_bbbfd th {
#   text-align: left;
# }
# #T_bbbfd tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_bbbfd tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_bbbfd .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_bbbfd_row0_col0, #T_bbbfd_row0_col1, #T_bbbfd_row0_col2, #T_bbbfd_row0_col3, #T_bbbfd_row0_col4, #T_bbbfd_row0_col5, #T_bbbfd_row0_col6, #T_bbbfd_row0_col7, #T_bbbfd_row0_col8, #T_bbbfd_row0_col9, #T_bbbfd_row0_col10, #T_bbbfd_row0_col13, #T_bbbfd_row0_col14, #T_bbbfd_row0_col15, #T_bbbfd_row1_col0, #T_bbbfd_row1_col1, #T_bbbfd_row1_col2, #T_bbbfd_row1_col3, #T_bbbfd_row1_col4, #T_bbbfd_row1_col5, #T_bbbfd_row1_col6, #T_bbbfd_row1_col7, #T_bbbfd_row1_col8, #T_bbbfd_row1_col9, #T_bbbfd_row1_col10, #T_bbbfd_row1_col13, #T_bbbfd_row1_col14, #T_bbbfd_row1_col15, #T_bbbfd_row2_col0, #T_bbbfd_row2_col1, #T_bbbfd_row2_col2, #T_bbbfd_row2_col3, #T_bbbfd_row2_col4, #T_bbbfd_row2_col5, #T_bbbfd_row2_col6, #T_bbbfd_row2_col7, #T_bbbfd_row2_col8, #T_bbbfd_row2_col9, #T_bbbfd_row2_col10, #T_bbbfd_row2_col13, #T_bbbfd_row2_col14, #T_bbbfd_row2_col15, #T_bbbfd_row3_col0, #T_bbbfd_row3_col1, #T_bbbfd_row3_col2, #T_bbbfd_row3_col3, #T_bbbfd_row3_col4, #T_bbbfd_row3_col5, #T_bbbfd_row3_col6, #T_bbbfd_row3_col7, #T_bbbfd_row3_col8, #T_bbbfd_row3_col9, #T_bbbfd_row3_col10, #T_bbbfd_row3_col13, #T_bbbfd_row3_col14, #T_bbbfd_row3_col15, #T_bbbfd_row4_col0, #T_bbbfd_row4_col1, #T_bbbfd_row4_col2, #T_bbbfd_row4_col3, #T_bbbfd_row4_col4, #T_bbbfd_row4_col5, #T_bbbfd_row4_col6, #T_bbbfd_row4_col7, #T_bbbfd_row4_col8, #T_bbbfd_row4_col9, #T_bbbfd_row4_col10, #T_bbbfd_row4_col13, #T_bbbfd_row4_col14, #T_bbbfd_row4_col15, #T_bbbfd_row5_col0, #T_bbbfd_row5_col1, #T_bbbfd_row5_col2, #T_bbbfd_row5_col3, #T_bbbfd_row5_col4, #T_bbbfd_row5_col5, #T_bbbfd_row5_col6, #T_bbbfd_row5_col7, #T_bbbfd_row5_col8, #T_bbbfd_row5_col9, #T_bbbfd_row5_col10, #T_bbbfd_row5_col13, #T_bbbfd_row5_col14, #T_bbbfd_row5_col15, #T_bbbfd_row6_col0, #T_bbbfd_row6_col1, #T_bbbfd_row6_col2, #T_bbbfd_row6_col3, #T_bbbfd_row6_col4, #T_bbbfd_row6_col5, #T_bbbfd_row6_col6, #T_bbbfd_row6_col7, #T_bbbfd_row6_col8, #T_bbbfd_row6_col9, #T_bbbfd_row6_col10, #T_bbbfd_row6_col13, #T_bbbfd_row6_col14, #T_bbbfd_row6_col15, #T_bbbfd_row7_col0, #T_bbbfd_row7_col1, #T_bbbfd_row7_col2, #T_bbbfd_row7_col3, #T_bbbfd_row7_col4, #T_bbbfd_row7_col5, #T_bbbfd_row7_col6, #T_bbbfd_row7_col7, #T_bbbfd_row7_col8, #T_bbbfd_row7_col9, #T_bbbfd_row7_col10, #T_bbbfd_row7_col13, #T_bbbfd_row7_col14, #T_bbbfd_row7_col15 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# #T_bbbfd_row0_col11, #T_bbbfd_row1_col11, #T_bbbfd_row2_col11, #T_bbbfd_row3_col11, #T_bbbfd_row4_col11, #T_bbbfd_row5_col11, #T_bbbfd_row6_col11, #T_bbbfd_row7_col11 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: #c3ffc4;
# }
# #T_bbbfd_row0_col12, #T_bbbfd_row1_col12, #T_bbbfd_row2_col12, #T_bbbfd_row3_col12, #T_bbbfd_row4_col12, #T_bbbfd_row5_col12, #T_bbbfd_row6_col12, #T_bbbfd_row7_col12 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: ;
# }
# </style>
# <table id="T_bbbfd">
#   <caption>Nodes</caption>
#   <thead>
#     <tr>
#       <th id="T_bbbfd_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_bbbfd_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_bbbfd_level0_col2" class="col_heading level0 col2" >Cores</th>
#       <th id="T_bbbfd_level0_col3" class="col_heading level0 col3" >RAM</th>
#       <th id="T_bbbfd_level0_col4" class="col_heading level0 col4" >Disk</th>
#       <th id="T_bbbfd_level0_col5" class="col_heading level0 col5" >Image</th>
#       <th id="T_bbbfd_level0_col6" class="col_heading level0 col6" >Image Type</th>
#       <th id="T_bbbfd_level0_col7" class="col_heading level0 col7" >Host</th>
#       <th id="T_bbbfd_level0_col8" class="col_heading level0 col8" >Site</th>
#       <th id="T_bbbfd_level0_col9" class="col_heading level0 col9" >Username</th>
#       <th id="T_bbbfd_level0_col10" class="col_heading level0 col10" >Management IP</th>
#       <th id="T_bbbfd_level0_col11" class="col_heading level0 col11" >State</th>
#       <th id="T_bbbfd_level0_col12" class="col_heading level0 col12" >Error</th>
#       <th id="T_bbbfd_level0_col13" class="col_heading level0 col13" >SSH Command</th>
#       <th id="T_bbbfd_level0_col14" class="col_heading level0 col14" >Public SSH Key File</th>
#       <th id="T_bbbfd_level0_col15" class="col_heading level0 col15" >Private SSH Key File</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_bbbfd_row0_col0" class="data row0 col0" >2e7a847a-cf53-4440-9104-5680cad7c7a2</td>
#       <td id="T_bbbfd_row0_col1" class="data row0 col1" >cont</td>
#       <td id="T_bbbfd_row0_col2" class="data row0 col2" >8</td>
#       <td id="T_bbbfd_row0_col3" class="data row0 col3" >16</td>
#       <td id="T_bbbfd_row0_col4" class="data row0 col4" >500</td>
#       <td id="T_bbbfd_row0_col5" class="data row0 col5" >default_ubuntu_20</td>
#       <td id="T_bbbfd_row0_col6" class="data row0 col6" >qcow2</td>
#       <td id="T_bbbfd_row0_col7" class="data row0 col7" >ucsd-w2.fabric-testbed.net</td>
#       <td id="T_bbbfd_row0_col8" class="data row0 col8" >UCSD</td>
#       <td id="T_bbbfd_row0_col9" class="data row0 col9" >ubuntu</td>
#       <td id="T_bbbfd_row0_col10" class="data row0 col10" >132.249.252.189</td>
#       <td id="T_bbbfd_row0_col11" class="data row0 col11" >Active</td>
#       <td id="T_bbbfd_row0_col12" class="data row0 col12" ></td>
#       <td id="T_bbbfd_row0_col13" class="data row0 col13" >ssh -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config ubuntu@132.249.252.189</td>
#       <td id="T_bbbfd_row0_col14" class="data row0 col14" >/home/fabric/work/fabric_config/slice_key.pub</td>
#       <td id="T_bbbfd_row0_col15" class="data row0 col15" >/home/fabric/work/fabric_config/slice_key</td>
#     </tr>
#     <tr>
#       <td id="T_bbbfd_row1_col0" class="data row1 col0" >a137b840-9f19-4f91-8a97-c0a863e050c4</td>
#       <td id="T_bbbfd_row1_col1" class="data row1 col1" >server1</td>
#       <td id="T_bbbfd_row1_col2" class="data row1 col2" >8</td>
#       <td id="T_bbbfd_row1_col3" class="data row1 col3" >16</td>
#       <td id="T_bbbfd_row1_col4" class="data row1 col4" >500</td>
#       <td id="T_bbbfd_row1_col5" class="data row1 col5" >default_ubuntu_20</td>
#       <td id="T_bbbfd_row1_col6" class="data row1 col6" >qcow2</td>
#       <td id="T_bbbfd_row1_col7" class="data row1 col7" >ucsd-w2.fabric-testbed.net</td>
#       <td id="T_bbbfd_row1_col8" class="data row1 col8" >UCSD</td>
#       <td id="T_bbbfd_row1_col9" class="data row1 col9" >ubuntu</td>
#       <td id="T_bbbfd_row1_col10" class="data row1 col10" >132.249.252.154</td>
#       <td id="T_bbbfd_row1_col11" class="data row1 col11" >Active</td>
#       <td id="T_bbbfd_row1_col12" class="data row1 col12" ></td>
#       <td id="T_bbbfd_row1_col13" class="data row1 col13" >ssh -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config ubuntu@132.249.252.154</td>
#       <td id="T_bbbfd_row1_col14" class="data row1 col14" >/home/fabric/work/fabric_config/slice_key.pub</td>
#       <td id="T_bbbfd_row1_col15" class="data row1 col15" >/home/fabric/work/fabric_config/slice_key</td>
#     </tr>
#     <tr>
#       <td id="T_bbbfd_row2_col0" class="data row2 col0" >369fb1c7-dc26-41cb-bd57-1c65e3a35b9a</td>
#       <td id="T_bbbfd_row2_col1" class="data row2 col1" >server2</td>
#       <td id="T_bbbfd_row2_col2" class="data row2 col2" >8</td>
#       <td id="T_bbbfd_row2_col3" class="data row2 col3" >16</td>
#       <td id="T_bbbfd_row2_col4" class="data row2 col4" >500</td>
#       <td id="T_bbbfd_row2_col5" class="data row2 col5" >default_ubuntu_20</td>
#       <td id="T_bbbfd_row2_col6" class="data row2 col6" >qcow2</td>
#       <td id="T_bbbfd
# <style type="text/css">
# #T_db1c6 caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_db1c6 th {
#   text-align: left;
# }
# #T_db1c6 tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_db1c6 tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_db1c6 .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_db1c6_row0_col0, #T_db1c6_row0_col1, #T_db1c6_row0_col2, #T_db1c6_row0_col3, #T_db1c6_row0_col4, #T_db1c6_row0_col5, #T_db1c6_row0_col6, #T_db1c6_row1_col0, #T_db1c6_row1_col1, #T_db1c6_row1_col2, #T_db1c6_row1_col3, #T_db1c6_row1_col4, #T_db1c6_row1_col5, #T_db1c6_row1_col6, #T_db1c6_row2_col0, #T_db1c6_row2_col1, #T_db1c6_row2_col2, #T_db1c6_row2_col3, #T_db1c6_row2_col4, #T_db1c6_row2_col5, #T_db1c6_row2_col6, #T_db1c6_row3_col0, #T_db1c6_row3_col1, #T_db1c6_row3_col2, #T_db1c6_row3_col3, #T_db1c6_row3_col4, #T_db1c6_row3_col5, #T_db1c6_row3_col6, #T_db1c6_row4_col0, #T_db1c6_row4_col1, #T_db1c6_row4_col2, #T_db1c6_row4_col3, #T_db1c6_row4_col4, #T_db1c6_row4_col5, #T_db1c6_row4_col6, #T_db1c6_row5_col0, #T_db1c6_row5_col1, #T_db1c6_row5_col2, #T_db1c6_row5_col3, #T_db1c6_row5_col4, #T_db1c6_row5_col5, #T_db1c6_row5_col6, #T_db1c6_row6_col0, #T_db1c6_row6_col1, #T_db1c6_row6_col2, #T_db1c6_row6_col3, #T_db1c6_row6_col4, #T_db1c6_row6_col5, #T_db1c6_row6_col6 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# #T_db1c6_row0_col7, #T_db1c6_row1_col7, #T_db1c6_row2_col7, #T_db1c6_row3_col7, #T_db1c6_row4_col7, #T_db1c6_row5_col7, #T_db1c6_row6_col7 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: #c3ffc4;
# }
# #T_db1c6_row0_col8, #T_db1c6_row1_col8, #T_db1c6_row2_col8, #T_db1c6_row3_col8, #T_db1c6_row4_col8, #T_db1c6_row5_col8, #T_db1c6_row6_col8 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: ;
# }
# </style>
# <table id="T_db1c6">
#   <caption>Networks</caption>
#   <thead>
#     <tr>
#       <th id="T_db1c6_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_db1c6_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_db1c6_level0_col2" class="col_heading level0 col2" >Layer</th>
#       <th id="T_db1c6_level0_col3" class="col_heading level0 col3" >Type</th>
#       <th id="T_db1c6_level0_col4" class="col_heading level0 col4" >Site</th>
#       <th id="T_db1c6_level0_col5" class="col_heading level0 col5" >Subnet</th>
#       <th id="T_db1c6_level0_col6" class="col_heading level0 col6" >Gateway</th>
#       <th id="T_db1c6_level0_col7" class="col_heading level0 col7" >State</th>
#       <th id="T_db1c6_level0_col8" class="col_heading level0 col8" >Error</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_db1c6_row0_col0" class="data row0 col0" >d8be3ba9-d85f-4bd1-84a2-b075d722effd</td>
#       <td id="T_db1c6_row0_col1" class="data row0 col1" >net1</td>
#       <td id="T_db1c6_row0_col2" class="data row0 col2" >L2</td>
#       <td id="T_db1c6_row0_col3" class="data row0 col3" >L2Bridge</td>
#       <td id="T_db1c6_row0_col4" class="data row0 col4" >UCSD</td>
#       <td id="T_db1c6_row0_col5" class="data row0 col5" >None</td>
#       <td id="T_db1c6_row0_col6" class="data row0 col6" >None</td>
#       <td id="T_db1c6_row0_col7" class="data row0 col7" >Active</td>
#       <td id="T_db1c6_row0_col8" class="data row0 col8" ></td>
#     </tr>
#     <tr>
#       <td id="T_db1c6_row1_col0" class="data row1 col0" >b9dc9249-c458-493d-9978-76e3f8b4331f</td>
#       <td id="T_db1c6_row1_col1" class="data row1 col1" >net2</td>
#       <td id="T_db1c6_row1_col2" class="data row1 col2" >L2</td>
#       <td id="T_db1c6_row1_col3" class="data row1 col3" >L2Bridge</td>
#       <td id="T_db1c6_row1_col4" class="data row1 col4" >UCSD</td>
#       <td id="T_db1c6_row1_col5" class="data row1 col5" >None</td>
#       <td id="T_db1c6_row1_col6" class="data row1 col6" >None</td>
#       <td id="T_db1c6_row1_col7" class="data row1 col7" >Active</td>
#       <td id="T_db1c6_row1_col8" class="data row1 col8" ></td>
#     </tr>
#     <tr>
#       <td id="T_db1c6_row2_col0" class="data row2 col0" >e3e90deb-b126-4fab-b68f-3cec70604302</td>
#       <td id="T_db1c6_row2_col1" class="data row2 col1" >net3</td>
#       <td id="T_db1c6_row2_col2" class="data row2 col2" >L2</td>
#       <td id="T_db1c6_row2_col3" class="data row2 col3" >L2Bridge</td>
#       <td id="T_db1c6_row2_col4" class="data row2 col4" >UCSD</td>
#       <td id="T_db1c6_row2_col5" class="data row2 col5" >None</td>
#       <td id="T_db1c6_row2_col6" class="data row2 col6" >None</td>
#       <td id="T_db1c6_row2_col7" class="data row2 col7" >Active</td>
#       <td id="T_db1c6_row2_col8" class="data row2 col8" ></td>
#     </tr>
#     <tr>
#       <td id="T_db1c6_row3_col0" class="data row3 col0" >5c579907-96c7-4152-b075-6ff50e3ecad1</td>
#       <td id="T_db1c6_row3_col1" class="data row3 col1" >net4</td>
#       <td id="T_db1c6_row3_col2" class="data row3 col2" >L2</td>
#       <td id="T_db1c6_row3_col3" class="data row3 col3" >L2Bridge</td>
#       <td id="T_db1c6_row3_col4" class="data row3 col4" >UCSD</td>
#       <td id="T_db1c6_row3_col5" class="data row3 col5" >None</td>
#       <td id="T_db1c6_row3_col6" class="data row3 col6" >None</td>
#       <td id="T_db1c6_row3_col7" class="data row3 col7" >Active</td>
#       <td id="T_db1c6_row3_col8" class="data row3 col8" ></td>
#     </tr>
#     <tr>
#       <td id="T_db1c6_row4_col0" class="data row4 col0" >d1518ca2-94ce-427b-89ec-d263651dce7c</td>
#       <td id="T_db1c6_row4_col1" class="data row4 col1" >net5</td>
#       <td id="T_db1c6_row4_col2" class="data row4 col2" >L2</td>
#       <td id="T_db1c6_row4_col3" class="data row4 col3" >L2Bridge</td>
#       <td id="T_db1c6_row4_col4" class="data row4 col4" >UCSD</td>
#       <td id="T_db1c6_row4_col5" class="data row4 col5" >None</td>
#       <td id="T_db1c6_row4_col6" class="data row4 col6" >None</td>
#       <td id="T_db1c6_row4_col7" class="data row4 col7" >Active</td>
#       <td id="T_db1c6_row4_col8" class="data row4 col8" ></td>
#     </tr>
#     <tr>
#       <td id="T_db1c6_row5_col0" class="data row5 col0" >06fbc4ff-bd46-4d11-93fa-39643ab4b899</td>
#       <td id="T_db1c6_row5_col1" class="data row5 col1" >net6</td>
#       <td id="T_db1c6_row5_col2" class="data row5 col2" >L2</td>
#       <td id="T_db1c6_row5_col3" class="data row5 col3" >L2Bridge</td>
#       <td id="T_db1c6_row5_col4" class="data row5 col4" >UCSD</td>
#       <td id="T_db1c6_row5_col5" class="data row5 col5" >None</td>
#       <td id="T_db1c6_row5_col6" class="data row5 col6" >None</td>
#       <td id="T_db1c6_row5_col7" class="data row5 col7" >Active</td>
#       <td id="T_db1c6_row5_col8" class="data row5 col8" ></td>
#     </tr>
#     <tr>
#       <td id="T_db1c6_row6_col0" class="data row6 col0" >90002480-f084-413f-901b-d4810b325675</td>
#       <td id="T_db1c6_row6_col1" class="data row6 col1" >net7</td>
#       <td id="T_db1c6_row6_col2" class="data row6 col2" >L2</td>
#       <td id="T_db1c6_row6_col3" class="data row6 col3" >L2Bridge</td>
#       <td id="T_db1c6_row6_col4" class="data row6 col4" >UCSD</td>
#       <td id="T_db1c6_row6_col5" class="data row6 col5" >None</td>
#       <td id="T_db1c6_row6_col6" class="data row6 col6" >None</td>
#       <td id="T_db1c6_row6_col7" class="data row6 col7" >Active</td>
#       <td id="T_db1c6_row6_col8" class="data row6 col8" ></td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_37aa2 caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_37aa2 th {
#   text-align: left;
# }
# #T_37aa2 tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_37aa2 tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_37aa2 .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_37aa2_row0_col0, #T_37aa2_row0_col1, #T_37aa2_row0_col2, #T_37aa2_row0_col3, #T_37aa2_row0_col4, #T_37aa2_row0_col5, #T_37aa2_row0_col6, #T_37aa2_row0_col7, #T_37aa2_row0_col8, #T_37aa2_row0_col9, #T_37aa2_row0_col10, #T_37aa2_row0_col11, #T_37aa2_row1_col0, #T_37aa2_row1_col1, #T_37aa2_row1_col2, #T_37aa2_row1_col3, #T_37aa2_row1_col4, #T_37aa2_row1_col5, #T_37aa2_row1_col6, #T_37aa2_row1_col7, #T_37aa2_row1_col8, #T_37aa2_row1_col9, #T_37aa2_row1_col10, #T_37aa2_row1_col11, #T_37aa2_row2_col0, #T_37aa2_row2_col1, #T_37aa2_row2_col2, #T_37aa2_row2_col3, #T_37aa2_row2_col4, #T_37aa2_row2_col5, #T_37aa2_row2_col6, #T_37aa2_row2_col7, #T_37aa2_row2_col8, #T_37aa2_row2_col9, #T_37aa2_row2_col10, #T_37aa2_row2_col11, #T_37aa2_row3_col0, #T_37aa2_row3_col1, #T_37aa2_row3_col2, #T_37aa2_row3_col3, #T_37aa2_row3_col4, #T_37aa2_row3_col5, #T_37aa2_row3_col6, #T_37aa2_row3_col7, #T_37aa2_row3_col8, #T_37aa2_row3_col9, #T_37aa2_row3_col10, #T_37aa2_row3_col11, #T_37aa2_row4_col0, #T_37aa2_row4_col1, #T_37aa2_row4_col2, #T_37aa2_row4_col3, #T_37aa2_row4_col4, #T_37aa2_row4_col5, #T_37aa2_row4_col6, #T_37aa2_row4_col7, #T_37aa2_row4_col8, #T_37aa2_row4_col9, #T_37aa2_row4_col10, #T_37aa2_row4_col11, #T_37aa2_row5_col0, #T_37aa2_row5_col1, #T_37aa2_row5_col2, #T_37aa2_row5_col3, #T_37aa2_row5_col4, #T_37aa2_row5_col5, #T_37aa2_row5_col6, #T_37aa2_row5_col7, #T_37aa2_row5_col8, #T_37aa2_row5_col9, #T_37aa2_row5_col10, #T_37aa2_row5_col11, #T_37aa2_row6_col0, #T_37aa2_row6_col1, #T_37aa2_row6_col2, #T_37aa2_row6_col3, #T_37aa2_row6_col4, #T_37aa2_row6_col5, #T_37aa2_row6_col6, #T_37aa2_row6_col7, #T_37aa2_row6_col8, #T_37aa2_row6_col9, #T_37aa2_row6_col10, #T_37aa2_row6_col11, #T_37aa2_row7_col0, #T_37aa2_row7_col1, #T_37aa2_row7_col2, #T_37aa2_row7_col3, #T_37aa2_row7_col4, #T_37aa2_row7_col5, #T_37aa2_row7_col6, #T_37aa2_row7_col7, #T_37aa2_row7_col8, #T_37aa2_row7_col9, #T_37aa2_row7_col10, #T_37aa2_row7_col11, #T_37aa2_row8_col0, #T_37aa2_row8_col1, #T_37aa2_row8_col2, #T_37aa2_row8_col3, #T_37aa2_row8_col4, #T_37aa2_row8_col5, #T_37aa2_row8_col6, #T_37aa2_row8_col7, #T_37aa2_row8_col8, #T_37aa2_row8_col9, #T_37aa2_row8_col10, #T_37aa2_row8_col11, #T_37aa2_row9_col0, #T_37aa2_row9_col1, #T_37aa2_row9_col2, #T_37aa2_row9_col3, #T_37aa2_row9_col4, #T_37aa2_row9_col5, #T_37aa2_row9_col6, #T_37aa2_row9_col7, #T_37aa2_row9_col8, #T_37aa2_row9_col9, #T_37aa2_row9_col10, #T_37aa2_row9_col11, #T_37aa2_row10_col0, #T_37aa2_row10_col1, #T_37aa2_row10_col2, #T_37aa2_row10_col3, #T_37aa2_row10_col4, #T_37aa2_row10_col5, #T_37aa2_row10_col6, #T_37aa2_row10_col7, #T_37aa2_row10_col8, #T_37aa2_row10_col9, #T_37aa2_row10_col10, #T_37aa2_row10_col11, #T_37aa2_row11_col0, #T_37aa2_row11_col1, #T_37aa2_row11_col2, #T_37aa2_row11_col3, #T_37aa2_row11_col4, #T_37aa2_row11_col5, #T_37aa2_row11_col6, #T_37aa2_row11_col7, #T_37aa2_row11_col8, #T_37aa2_row11_col9, #T_37aa2_row11_col10, #T_37aa2_row11_col11, #T_37aa2_row12_col0, #T_37aa2_row12_col1, #T_37aa2_row12_col2, #T_37aa2_row12_col3, #T_37aa2_row12_col4, #T_37aa2_row12_col5, #T_37aa2_row12_col6, #T_37aa2_row12_col7, #T_37aa2_row12_col8, #T_37aa2_row12_col9, #T_37aa2_row12_col10, #T_37aa2_row12_col11, #T_37aa2_row13_col0, #T_37aa2_row13_col1, #T_37aa2_row13_col2, #T_37aa2_row13_col3, #T_37aa2_row13_col4, #T_37aa2_row13_col5, #T_37aa2_row13_col6, #T_37aa2_row13_col7, #T_37aa2_row13_col8, #T_37aa2_row13_col9, #T_37aa2_row13_col10, #T_37aa2_row13_col11 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_37aa2">
#   <caption>Interfaces</caption>
#   <thead>
#     <tr>
#       <th id="T_37aa2_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_37aa2_level0_col1" class="col_heading level0 col1" >Short Name</th>
#       <th id="T_37aa2_level0_col2" class="col_heading level0 col2" >Node</th>
#       <th id="T_37aa2_level0_col3" class="col_heading level0 col3" >Network</th>
#       <th id="T_37aa2_level0_col4" class="col_heading level0 col4" >Bandwidth</th>
#       <th id="T_37aa2_level0_col5" class="col_heading level0 col5" >Mode</th>
#       <th id="T_37aa2_level0_col6" class="col_heading level0 col6" >VLAN</th>
#       <th id="T_37aa2_level0_col7" class="col_heading level0 col7" >MAC</th>
#       <th id="T_37aa2_level0_col8" class="col_heading level0 col8" >Physical Device</th>
#       <th id="T_37aa2_level0_col9" class="col_heading level0 col9" >Device</th>
#       <th id="T_37aa2_level0_col10" class="col_heading level0 col10" >IP Address</th>
#       <th id="T_37aa2_level0_col11" class="col_heading level0 col11" >Numa Node</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_37aa2_row0_col0" class="data row0 col0" >server1-None-p1</td>
#       <td id="T_37aa2_row0_col1" class="data row0 col1" >p1</td>
#       <td id="T_37aa2_row0_col2" class="data row0 col2" >server1</td>
#       <td id="T_37aa2_row0_col3" class="data row0 col3" >net1</td>
#       <td id="T_37aa2_row0_col4" class="data row0 col4" >100</td>
#       <td id="T_37aa2_row0_col5" class="data row0 col5" >config</td>
#       <td id="T_37aa2_row0_col6" class="data row0 col6" ></td>
#       <td id="T_37aa2_row0_col7" class="data row0 col7" >16:AE:F8:09:05:1E</td>
#       <td id="T_37aa2_row0_col8" class="data row0 col8" >enp6s0</td>
#       <td id="T_37aa2_row0_col9" class="data row0 col9" >enp6s0</td>
#       <td id="T_37aa2_row0_col10" class="data row0 col10" >None</td>
#       <td id="T_37aa2_row0_col11" class="data row0 col11" >6</td>
#     </tr>
#     <tr>
#       <td id="T_37aa2_row1_col0" class="data row1 col0" >server1-s1_net2_nic-p1</td>
#       <td id="T_37aa2_row1_col1" class="data row1 col1" >p1</td>
#       <td id="T_37aa2_row1_col2" class="data row1 col2" >server1</td>
#       <td id="T_37aa2_row1_col3" class="data row1 col3" >net6</td>
#       <td id="T_37aa2_row1_col4" class="data row1 col4" >100</td>
#       <td id="T_37aa2_row1_col5" class="data row1 col5" >config</td>
#       <td id="T_37aa2_row1_col6" class="data row1 col6" ></td>
#       <td id="T_37aa2_row1_col7" class="data row1 col7" >1A:07:73:69:9A:1C</td>
#       <td id="T_37aa2_row1_col8" class="data row1 col8" >enp7s0</td>
#       <td id="T_37aa2_row1_col9" class="data row1 col9" >enp7s0</td>
#       <td id="T_37aa2_row1_col10" class="data row1 col10" >None</td>
#       <td id="T_37aa2_row1_col11" class="data row1 col11" >6</td>
#     </tr>
#     <tr>
#       <td id="T_37aa2_row2_col0" class="data row2 col0" >server2-None-p1</td>
#       <td id="T_37aa2_row2_col1" class="data row2 col1" >p1</td>
#       <td id="T_37aa2_row2_col2" class="data row2 col2" >server2</td>
#       <td id="T_37aa2_row2_col3" class="data row2 col3" >net2</td>
#       <td id="T_37aa2_row2_col4" class="data row2 col4" >100</td>
#       <td id="T_37aa2_row2_col5" class="data row2 col5" >config</td>
#       <td id="T_37aa2_row2_col6" class="data row2 col6" ></td>
#       <td id="T_37aa2_row2_col7" class="data row2 col7" >1A:52:A9:BB:94:C0</td>
#       <td id="T_37aa2_row2_col8" class="data row2 col8" >enp6s0</td>
#       <td id="T_37aa2_row2_col9" class="data row2 col9" >enp6s0</td>
#       <td id="T_37aa2_row2_col10" class="data row2 col10" >None</td>
#       <td id="T_37aa2_row2_col11" class="data row2 col11" >6</td>
#     </tr>
#     <tr>
#       <td id="T_37aa2_row3_col0" class="data row3 col0" >user1-None-p1</td>
#       <td id="T_37aa2_row3_col1" class="data row3 col1" >p1</td>
#       <td id="T_37aa2_row3_col2" class="data row3 col2" >user1</td>
#       <td id="T_37aa2_row3_col3" class="data row3 col3" >net3</td>
#       <td id="T_37aa2_row3_col4" class="data row3 col4" >100</td>
#       <td id="T_37aa2_row3_col5" class="data row3 col5" >config</td>
#       <td id="T_37aa2_row3_
# Time to print interfaces 900 seconds

# %%
switch = slice.get_node(name="switch")     
switch.upload_file('scripts/install_bmv2.sh', 'install_bmv2.sh')
stdout, stderr = switch.execute(f'chmod +x install_bmv2.sh &&  ./install_bmv2.sh',quiet=True)

# %%
#2
switch2 = slice.get_node(name="switch2")     
switch2.upload_file('scripts/install_bmv2.sh', 'install_bmv2.sh')
stdout, stderr = switch2.execute(f'chmod +x install_bmv2.sh &&  ./install_bmv2.sh',quiet=True)

# %%
server1 = slice.get_node(name="server1")
server2 = slice.get_node(name="server2")
user1 = slice.get_node(name="user1")
user2 = slice.get_node(name="user2")
cont = slice.get_node(name="cont")

stdout, stderr = server1.execute(f'sudo apt-get install -y net-tools', quiet=True)
stdout, stderr = server2.execute(f'sudo apt-get install -y net-tools', quiet=True)
stdout, stderr = switch.execute(f'sudo apt-get install -y net-tools', quiet=True)
stdout, stderr = user1.execute(f'sudo apt-get install -y net-tools', quiet=True)
stdout, stderr = user2.execute(f'sudo apt-get install -y net-tools', quiet=True)
stdout, stderr = cont.execute(f'sudo apt-get install -y net-tools', quiet=True)

stdout, stderr = server1.execute(f'sudo apt install python3-scapy', quiet=True)
stdout, stderr = server2.execute(f'sudo apt install python3-scapy', quiet=True)
stdout, stderr = switch.execute(f'sudo apt install python3-scapy', quiet=True)
stdout, stderr = user1.execute(f'sudo apt install python3-scapy', quiet=True)
stdout, stderr = user2.execute(f'sudo apt install python3-scapy', quiet=True)
stdout, stderr = cont.execute(f'sudo apt install python3-scapy', quiet=True)

# %%
#2
server3 = slice.get_node(name="server3")
stdout, stderr = server3.execute(f'sudo apt-get install -y net-tools', quiet=True)
stdout, stderr = server3.execute(f'sudo apt install python3-scapy', quiet=True)
stdout, stderr = switch2.execute(f'sudo apt install python3-scapy', quiet=True)
stdout, stderr = switch2.execute(f'sudo apt-get install -y net-tools', quiet=True)

# %%
node1_iface = server1.get_interface(network_name='net1') 
server1_iface_name = node1_iface.get_device_name()
print(f'server1_iface: {server1_iface_name}')

node2_iface = server2.get_interface(network_name='net2') 
server2_iface_name = node2_iface.get_device_name()
print(f'server2_iface: {server2_iface_name}')

user1_iface = user1.get_interface(network_name='net3') 
user1_iface_name = user1_iface.get_device_name()
print(f'User1_iface: {user1_iface_name}')

user2_iface = user2.get_interface(network_name='net4') 
user2_iface_name = user2_iface.get_device_name()
print(f'User2_iface: {user2_iface_name}')

cont_iface = cont.get_interface(network_name='net5') 
cont_iface_name = cont_iface.get_device_name()
print(f'Cont_iface: {cont_iface_name}')

switch_iface1 = switch.get_interface(network_name='net1') 
switch_iface1_name = switch_iface1.get_device_name()
print(f'switch_iface1: {switch_iface1_name}')

switch_iface2 = switch.get_interface(network_name='net2') 
switch_iface2_name = switch_iface2.get_device_name()
print(f'switch_iface2: {switch_iface2_name}')

switch_iface3 = switch.get_interface(network_name='net3') 
switch_iface3_name = switch_iface3.get_device_name()
print(f'switch_iface3: {switch_iface3_name}')

switch_iface4 = switch.get_interface(network_name='net4') 
switch_iface4_name = switch_iface4.get_device_name()
print(f'switch_iface4: {switch_iface4_name}')

switch_iface5 = switch.get_interface(network_name='net5') 
switch_iface5_name = switch_iface5.get_device_name()
print(f'switch_iface5: {switch_iface5_name}')
# Out:
# server1_iface: enp6s0
# server2_iface: enp6s0
# User1_iface: enp6s0
# User2_iface: enp6s0
# Cont_iface: enp6s0
# switch_iface1: enp6s0
# switch_iface2: enp9s0
# switch_iface3: enp7s0
# switch_iface4: enp10s0
# switch_iface5: enp8s0

# %%
#2
node1_iface2 = server1.get_interface(network_name='net6') 
server1_iface2_name = node1_iface2.get_device_name()
print(f'server1_iface2: {server1_iface2_name}')

node3_iface = server3.get_interface(network_name='net7') 
server3_iface_name = node3_iface.get_device_name()
print(f'server3_iface: {server3_iface_name}')

switch2_iface1 = switch2.get_interface(network_name='net6') 
switch2_iface1_name = switch2_iface1.get_device_name()
print(f'switch2_iface1: {switch2_iface1_name}')

switch2_iface2 = switch2.get_interface(network_name='net7') 
switch2_iface2_name = switch2_iface2.get_device_name()
print(f'switch2_iface2: {switch2_iface2_name}')
# Out:
# server1_iface2: enp7s0
# server3_iface: enp6s0
# switch2_iface1: enp7s0
# switch2_iface2: enp6s0

# %%
stdout, stderr = server1.execute(f'sudo ip link set dev {server1_iface_name} up', quiet=True)
stdout, stderr = server2.execute(f'sudo ip link set dev {server2_iface_name} up', quiet=True)
stdout, stderr = user1.execute(f'sudo ip link set dev {user1_iface_name} up', quiet=True)
stdout, stderr = user2.execute(f'sudo ip link set dev {user2_iface_name} up', quiet=True)
stdout, stderr = cont.execute(f'sudo ip link set dev {cont_iface_name} up', quiet=True)

stdout, stderr = switch.execute(f'sudo ip link set dev {switch_iface1_name} up', quiet=True)
stdout, stderr = switch.execute(f'sudo ip link set dev {switch_iface2_name} up', quiet=True)
stdout, stderr = switch.execute(f'sudo ip link set dev {switch_iface3_name} up', quiet=True)
stdout, stderr = switch.execute(f'sudo ip link set dev {switch_iface4_name} up', quiet=True)
stdout, stderr = switch.execute(f'sudo ip link set dev {switch_iface5_name} up', quiet=True)

# %%
#2
stdout, stderr = server1.execute(f'sudo ip link set dev {server1_iface2_name} up', quiet=True)
stdout, stderr = server3.execute(f'sudo ip link set dev {server3_iface_name} up', quiet=True)

stdout, stderr = switch2.execute(f'sudo ip link set dev {switch2_iface1_name} up', quiet=True)
stdout, stderr = switch2.execute(f'sudo ip link set dev {switch2_iface2_name} up', quiet=True)

# %%
server1_iface_MAC = '00:00:00:00:00:01'
switch_iface1_MAC = '00:00:00:00:00:02'
switch_iface2_MAC = '00:00:00:00:00:03'
server2_iface_MAC = '00:00:00:00:00:04'

user1_iface_MAC = '00:00:00:00:00:05'
switch_iface3_MAC = '00:00:00:00:00:06'
switch_iface4_MAC = '00:00:00:00:00:07'
user2_iface_MAC = '00:00:00:00:00:08'

switch_iface5_MAC = '00:00:00:00:00:09'
cont_iface_MAC = '00:00:00:00:00:10'

# %%
#2 
server1_iface2_MAC = '00:00:00:00:00:11'
switch2_iface1_MAC = '00:00:00:00:00:12'
switch2_iface2_MAC = '00:00:00:00:00:13'
server3_iface_MAC = '00:00:00:00:00:14'

# %%
server1_switch_subnet = "192.168.1.0/24"
server1_ip = '192.168.1.10/24'
switch_ip1 = '192.168.1.1/24'

stdout, stderr = server1.execute(f'sudo ifconfig {server1_iface_name} {server1_ip}')
stdout, stderr = switch.execute(f'sudo ifconfig {switch_iface1_name} {switch_ip1}')
print("sudo ifconfig {} {} ".format(server1_iface_name,server1_ip))
print("sudo ifconfig {} {} ".format(switch_iface1_name,switch_ip1))

stdout, stderr = server1.execute(f'sudo ifconfig {server1_iface_name} hw ether {server1_iface_MAC}')
stdout, stderr = switch.execute(f'sudo ifconfig {switch_iface1_name} hw ether {switch_iface1_MAC}')

print("sudo ifconfig {} hw ether {} ".format(server1_iface_name,server1_iface_MAC))
print("sudo ifconfig {} hw ether {} ".format(switch_iface1_name,switch_iface1_MAC))
# Out:
# sudo ifconfig enp6s0 192.168.1.10/24
# sudo ifconfig enp6s0 192.168.1.1/24
# sudo ifconfig enp6s0 hw ether 00:00:00:00:00:01
# sudo ifconfig enp6s0 hw ether 00:00:00:00:00:02

# %%
server2_switch_subnet = "192.168.2.0/24"
server2_ip = '192.168.2.10/24'
switch_ip2 = '192.168.2.1/24'

stdout, stderr = server2.execute(f'sudo ifconfig {server2_iface_name} {server2_ip}')
stdout, stderr = switch.execute(f'sudo ifconfig {switch_iface2_name} {switch_ip2}')

print("sudo ifconfig {} {} ".format(server2_iface_name,server2_ip))
print("sudo ifconfig {} {} ".format(switch_iface2_name,switch_ip2))

stdout, stderr = server2.execute(f'sudo ifconfig {server2_iface_name} hw ether {server2_iface_MAC}')
stdout, stderr = switch.execute(f'sudo ifconfig {switch_iface2_name} hw ether {switch_iface2_MAC}')
print("sudo ifconfig {} hw ether {} ".format(server2_iface_name,server2_iface_MAC))
print("sudo ifconfig {} hw ether {} ".format(switch_iface2_name,switch_iface2_MAC))
# Out:
# sudo ifconfig enp6s0 192.168.2.10/24
# sudo ifconfig enp9s0 192.168.2.1/24
# sudo ifconfig enp6s0 hw ether 00:00:00:00:00:04
# sudo ifconfig enp9s0 hw ether 00:00:00:00:00:03

# %%
user1_switch_subnet = "192.168.3.0/24"
user1_ip = '192.168.3.10/24'
switch_ip3 = '192.168.3.1/24'

stdout, stderr = user1.execute(f'sudo ifconfig {user1_iface_name} {user1_ip}')
stdout, stderr = switch.execute(f'sudo ifconfig {switch_iface3_name} {switch_ip3}')
print("sudo ifconfig {} {} ".format(user1_iface_name,user1_ip))
print("sudo ifconfig {} {} ".format(switch_iface3_name,switch_ip3))

stdout, stderr = user1.execute(f'sudo ifconfig {user1_iface_name} hw ether {user1_iface_MAC}')
stdout, stderr = switch.execute(f'sudo ifconfig {switch_iface3_name} hw ether {switch_iface3_MAC}')

print("sudo ifconfig {} hw ether {} ".format(user1_iface_name,user1_iface_MAC))
print("sudo ifconfig {} hw ether {} ".format(switch_iface3_name,switch_iface3_MAC))
# Out:
# sudo ifconfig enp6s0 192.168.3.10/24
# sudo ifconfig enp7s0 192.168.3.1/24
# sudo ifconfig enp6s0 hw ether 00:00:00:00:00:05
# sudo ifconfig enp7s0 hw ether 00:00:00:00:00:06

# %%
user2_switch_subnet = "192.168.4.0/24"
user2_ip = '192.168.4.10/24'
switch_ip4 = '192.168.4.1/24'

stdout, stderr = user2.execute(f'sudo ifconfig {user2_iface_name} {user2_ip}')
stdout, stderr = switch.execute(f'sudo ifconfig {switch_iface4_name} {switch_ip4}')
print("sudo ifconfig {} {} ".format(user2_iface_name,user2_ip))
print("sudo ifconfig {} {} ".format(switch_iface4_name,switch_ip4))

stdout, stderr = user2.execute(f'sudo ifconfig {user2_iface_name} hw ether {user2_iface_MAC}')
stdout, stderr = switch.execute(f'sudo ifconfig {switch_iface4_name} hw ether {switch_iface4_MAC}')

print("sudo ifconfig {} hw ether {} ".format(user2_iface_name,user2_iface_MAC))
print("sudo ifconfig {} hw ether {} ".format(switch_iface4_name,switch_iface4_MAC))
# Out:
# sudo ifconfig enp6s0 192.168.4.10/24
# sudo ifconfig enp10s0 192.168.4.1/24
# sudo ifconfig enp6s0 hw ether 00:00:00:00:00:08
# sudo ifconfig enp10s0 hw ether 00:00:00:00:00:07

# %%
cont_switch_subnet = "192.168.5.0/24"
cont_ip = '192.168.5.10/24'
switch_ip5 = '192.168.5.1/24'

stdout, stderr = cont.execute(f'sudo ifconfig {cont_iface_name} {cont_ip}')
stdout, stderr = switch.execute(f'sudo ifconfig {switch_iface5_name} {switch_ip5}')
print("sudo ifconfig {} {} ".format(cont_iface_name,cont_ip))
print("sudo ifconfig {} {} ".format(switch_iface5_name,switch_ip5))

stdout, stderr = cont.execute(f'sudo ifconfig {cont_iface_name} hw ether {cont_iface_MAC}')
stdout, stderr = switch.execute(f'sudo ifconfig {switch_iface5_name} hw ether {switch_iface5_MAC}')

print("sudo ifconfig {} hw ether {} ".format(cont_iface_name,cont_iface_MAC))
print("sudo ifconfig {} hw ether {} ".format(switch_iface5_name,switch_iface5_MAC))
# Out:
# sudo ifconfig enp6s0 192.168.5.10/24
# sudo ifconfig enp8s0 192.168.5.1/24
# sudo ifconfig enp6s0 hw ether 00:00:00:00:00:10
# sudo ifconfig enp8s0 hw ether 00:00:00:00:00:09

# %%
#2 This is important
server1_ip2 = '192.168.1.9/24'
switch2_ip1 = '192.168.1.2/24'

stdout, stderr = server1.execute(f'sudo ifconfig {server1_iface2_name} {server1_ip2}')
stdout, stderr = switch2.execute(f'sudo ifconfig {switch2_iface1_name} {switch2_ip1}')
print("sudo ifconfig {} {} ".format(server1_iface2_name,server1_ip2))
print("sudo ifconfig {} {} ".format(switch2_iface1_name,switch2_ip1))

stdout, stderr = server1.execute(f'sudo ifconfig {server1_iface2_name} hw ether {server1_iface2_MAC}')
stdout, stderr = switch2.execute(f'sudo ifconfig {switch2_iface1_name} hw ether {switch2_iface1_MAC}')

print("sudo ifconfig {} hw ether {} ".format(server1_iface2_name,server1_iface2_MAC))
print("sudo ifconfig {} hw ether {} ".format(switch2_iface1_name,switch2_iface1_MAC))
# Out:
# sudo ifconfig enp7s0 192.168.1.9/24
# sudo ifconfig enp7s0 192.168.1.1/24
# sudo ifconfig enp7s0 hw ether 00:00:00:00:00:11
# sudo ifconfig enp7s0 hw ether 00:00:00:00:00:12

# %%
#2
server3_switch_subnet = "192.168.7.0/24"
server3_ip = '192.168.7.10/24'
switch2_ip2 = '192.168.7.1/24'

stdout, stderr = server3.execute(f'sudo ifconfig {server3_iface_name} {server3_ip}')
stdout, stderr = switch2.execute(f'sudo ifconfig {switch2_iface2_name} {switch2_ip2}')

print("sudo ifconfig {} {} ".format(server3_iface_name,server3_ip))
print("sudo ifconfig {} {} ".format(switch2_iface2_name,switch2_ip2))

stdout, stderr = server3.execute(f'sudo ifconfig {server3_iface_name} hw ether {server3_iface_MAC}')
stdout, stderr = switch2.execute(f'sudo ifconfig {switch2_iface2_name} hw ether {switch2_iface2_MAC}')
print("sudo ifconfig {} hw ether {} ".format(server3_iface_name,server3_iface_MAC))
print("sudo ifconfig {} hw ether {} ".format(switch2_iface2_name,switch2_iface2_MAC))
# Out:
# sudo ifconfig enp6s0 192.168.7.10/24
# sudo ifconfig enp6s0 192.168.7.1/24
# sudo ifconfig enp6s0 hw ether 00:00:00:00:00:14
# sudo ifconfig enp6s0 hw ether 00:00:00:00:00:13

# %%
stdout, stderr = switch.execute('sudo sysctl -w net.ipv4.ip_forward=1' , quiet=True)

# %%
stdout, stderr = switch2.execute('sudo sysctl -w net.ipv4.ip_forward=1' , quiet=True)

# %%
stdout, stderr = switch.execute(f'sudo ip route del {server1_switch_subnet}', quiet=True)
stdout, stderr = switch.execute(f'sudo ip route del {server2_switch_subnet}', quiet=True)
stdout, stderr = switch.execute(f'sudo ip route del {user1_switch_subnet}', quiet=True)
stdout, stderr = switch.execute(f'sudo ip route del {user2_switch_subnet}', quiet=True)
stdout, stderr = switch.execute(f'sudo ip route del {cont_switch_subnet}', quiet=True)

print("sudo ip route del {} ".format(server1_switch_subnet))
print("sudo ip route del {} ".format(server2_switch_subnet))
print("sudo ip route del {} ".format(user1_switch_subnet))
print("sudo ip route del {} ".format(user2_switch_subnet))
print("sudo ip route del {} ".format(cont_switch_subnet))
# Out:
# sudo ip route del 192.168.1.0/24
# sudo ip route del 192.168.2.0/24
# sudo ip route del 192.168.3.0/24
# sudo ip route del 192.168.4.0/24
# sudo ip route del 192.168.5.0/24

# %%
#2 
stdout, stderr = switch2.execute(f'sudo ip route del {server1_switch_subnet}', quiet=True)
stdout, stderr = switch2.execute(f'sudo ip route del {server3_switch_subnet}', quiet=True)
print("sudo ip route del {} ".format(server1_switch_subnet))
print("sudo ip route del {} ".format(server3_switch_subnet))
# Out:
# sudo ip route del 192.168.1.0/24
# sudo ip route del 192.168.7.0/24

# %%
gw1 = switch_ip1.split('/')[0] # gw1 -> 192.168.1.1 
gw2 = switch_ip2.split('/')[0] # gw2 -> 192.168.2.1
gw3 = switch_ip3.split('/')[0] # gw3 -> 192.168.3.1 
gw4 = switch_ip4.split('/')[0] # gw4 -> 192.168.4.1
gw5 = switch_ip5.split('/')[0] # gw5 -> 192.168.5.1

stdout, stderr = server1.execute(f'sudo ip route add {server2_switch_subnet} via {gw1}')
stdout, stderr = server1.execute(f'sudo ip route add {user1_switch_subnet} via {gw1}')
stdout, stderr = server1.execute(f'sudo ip route add {user2_switch_subnet} via {gw1}')
stdout, stderr = server1.execute(f'sudo ip route add {cont_switch_subnet} via {gw1}')

stdout, stderr = server2.execute(f'sudo ip route add {server1_switch_subnet} via {gw2}')
stdout, stderr = server2.execute(f'sudo ip route add {user1_switch_subnet} via {gw2}')
stdout, stderr = server2.execute(f'sudo ip route add {user2_switch_subnet} via {gw2}')
stdout, stderr = server2.execute(f'sudo ip route add {cont_switch_subnet} via {gw2}')

stdout, stderr = user1.execute(f'sudo ip route add {user2_switch_subnet} via {gw3}')
stdout, stderr = user1.execute(f'sudo ip route add {server1_switch_subnet} via {gw3}')
stdout, stderr = user1.execute(f'sudo ip route add {server2_switch_subnet} via {gw3}')
stdout, stderr = user1.execute(f'sudo ip route add {cont_switch_subnet} via {gw3}')

stdout, stderr = user2.execute(f'sudo ip route add {user1_switch_subnet} via {gw4}')
stdout, stderr = user2.execute(f'sudo ip route add {server1_switch_subnet} via {gw4}')
stdout, stderr = user2.execute(f'sudo ip route add {server2_switch_subnet} via {gw4}')
stdout, stderr = user2.execute(f'sudo ip route add {cont_switch_subnet} via {gw4}')

stdout, stderr = cont.execute(f'sudo ip route add {server1_switch_subnet} via {gw5}')
stdout, stderr = cont.execute(f'sudo ip route add {server2_switch_subnet} via {gw5}')
stdout, stderr = cont.execute(f'sudo ip route add {user1_switch_subnet} via {gw5}')
stdout, stderr = cont.execute(f'sudo ip route add {user2_switch_subnet} via {gw5}')

print("sudo ip route add {} via {} ".format(server2_switch_subnet,gw1))
print("sudo ip route add {} via {} ".format(server1_switch_subnet,gw2))
print("sudo ip route add {} via {} ".format(user2_switch_subnet,gw3))
print("sudo ip route add {} via {} ".format(user1_switch_subnet,gw4))
print("sudo ip route add {} via {} ".format(cont_switch_subnet,gw5))
# Out:
# sudo ip route add 192.168.2.0/24 via 192.168.1.1
# sudo ip route add 192.168.1.0/24 via 192.168.2.1
# sudo ip route add 192.168.4.0/24 via 192.168.3.1
# sudo ip route add 192.168.3.0/24 via 192.168.4.1
# sudo ip route add 192.168.5.0/24 via 192.168.5.1

# %%
#2 
gw6 = switch2_ip1.split('/')[0] # gw1 -> 192.168.1.1 
gw7 = switch2_ip2.split('/')[0] # gw2 -> 192.168.7.1
stdout, stderr = server1.execute(f'sudo ip route add {server3_switch_subnet} via {gw6} dev {server1_iface2_name}')
stdout, stderr = server3.execute(f'sudo ip route add {server1_switch_subnet} via {gw7}')
print("sudo ip route add {} via {} dev {}".format(server1_switch_subnet,gw6,server1_iface2_name))
print("sudo ip route add {} via {} ".format(server3_switch_subnet,gw7))
# Out:
#  RTNETLINK answers: File exists
#   RTNETLINK answers: File exists
#  sudo ip route add 192.168.1.0/24 via 192.168.1.1 dev enp7s0
# sudo ip route add 192.168.7.0/24 via 192.168.7.1

# %%
stdout, stderr = server1.execute(f'sudo arp -s {gw1} {switch_iface1_MAC}')
stdout, stderr = server2.execute(f'sudo arp -s {gw2} {switch_iface2_MAC}')
stdout, stderr = user1.execute(f'sudo arp -s {gw3} {switch_iface3_MAC}')
stdout, stderr = user2.execute(f'sudo arp -s {gw4} {switch_iface4_MAC}')
stdout, stderr = cont.execute(f'sudo arp -s {gw5} {switch_iface5_MAC}')

print(" sudo arp -s {} {} ".format(gw1,switch_iface1_MAC))
print(" sudo arp -s {} {} ".format(gw2,switch_iface2_MAC))
print(" sudo arp -s {} {} ".format(gw3,switch_iface3_MAC))
print(" sudo arp -s {} {} ".format(gw4,switch_iface4_MAC))
print(" sudo arp -s {} {} ".format(gw5,switch_iface5_MAC))
# Out:
#  sudo arp -s 192.168.1.1 00:00:00:00:00:02
#  sudo arp -s 192.168.2.1 00:00:00:00:00:03
#  sudo arp -s 192.168.3.1 00:00:00:00:00:06
#  sudo arp -s 192.168.4.1 00:00:00:00:00:07
#  sudo arp -s 192.168.5.1 00:00:00:00:00:09

# %%
#2 How to ARP on certain ethernet device ? 
stdout, stderr = server1.execute(f'sudo arp -s {gw6} {switch2_iface1_MAC}')
stdout, stderr = server3.execute(f'sudo arp -s {gw7} {switch2_iface2_MAC}')

print(" sudo arp -s {} {} ".format(gw6,switch2_iface1_MAC))
print(" sudo arp -s {} {} ".format(gw7,switch2_iface2_MAC))
# Out:
#  sudo arp -s 192.168.1.1 00:00:00:00:00:12
#  sudo arp -s 192.168.7.1 00:00:00:00:00:13

# %%
switch.upload_file('labs_files/lab1/main.p4', 'main.p4')
stdout, stderr = switch.execute(f'p4c main.p4')
stdout, stderr = switch.execute(f'sudo pkill simple_switch')
stdout, stderr = switch.execute(f'sudo simple_switch -i 0@{switch_iface1_name} -i 1@{switch_iface2_name} -i 2@{switch_iface3_name} -i 3@{switch_iface4_name} -i 4@{switch_iface5_name} main.json &')
# Out:
# Calling target program-options parser
# Adding interface enp6s0 as port 0
# Adding interface enp9s0 as port 1
# Adding interface enp7s0 as port 2
# Adding interface enp10s0 as port 3
# Adding interface enp8s0 as port 4

# %%
#2
switch2.upload_file('labs_files/lab1/main.p4', 'main.p4')
stdout, stderr = switch2.execute(f'p4c main.p4')
stdout, stderr = switch2.execute(f'sudo pkill simple_switch')
stdout, stderr = switch2.execute(f'sudo simple_switch -i 0@{switch2_iface1_name} -i 1@{switch2_iface2_name}  main.json &')
# Out:
# Calling target program-options parser
# Adding interface enp7s0 as port 0
# Adding interface enp6s0 as port 1

# %%
stdout, stderr = switch.execute('sudo rm 5sr.sh' , quiet=True)
switch.upload_file('labs_files/lab1/5sr.sh', '5sr.sh')
stdout, stderr = switch.execute('chmod +x 5sr.sh && ./5sr.sh')
# Out:
# Obtaining JSON from switch...
# Done
# Control utility for runtime P4 table manipulation
# RuntimeCmd: Adding entry to lpm match table MyIngress.ipv4_lpm
# match key:           LPM-c0:a8:01:00/24
# action:              MyIngress.forward
# runtime data:        00:00:00:00:00:01	00:00
# Entry has been added with handle 0
# RuntimeCmd:
# Obtaining JSON from switch...
# Done
# Control utility for runtime P4 table manipulation
# RuntimeCmd: Adding entry to lpm match table MyIngress.ipv4_lpm
# match key:           LPM-c0:a8:02:00/24
# action:              MyIngress.forward
# runtime data:        00:00:00:00:00:04	00:01
# Entry has been added with handle 1
# RuntimeCmd:
# Obtaining JSON from switch...
# Done
# Control utility for runtime P4 table manipulation
# RuntimeCmd: Adding entry to lpm match table MyIngress.ipv4_lpm
# match key:           LPM-c0:a8:03:00/24
# action:              MyIngress.forward
# runtime data:        00:00:00:00:00:05	00:02
# Entry has been added with handle 2
# RuntimeCmd:
# Obtaining JSON from switch...
# Done
# Control utility for runtime P4 table manipulation
# RuntimeCmd: Adding entry to lpm match table MyIngress.ipv4_lpm
# match key:           LPM-c0:a8:04:00/24
# action:              MyIngress.forward
# runtime data:        00:00:00:00:00:08	00:03
# Entry has been added with handle 3
# RuntimeCmd:
# Obtaining JSON from switch...
# Done
# Control utility for runtime P4 table manipulation
# RuntimeCmd: Adding entry to lpm match table MyIngress.ipv4_lpm
# match key:           LPM-c0:a8:05:00/24
# action:              MyIngress.forward
# runtime data:        00:00:00:00:00:10	00:04
# Entry has been added with handle 4
# RuntimeCmd:

# %%
#2
stdout, stderr = switch2.execute('sudo rm 25sr.sh' , quiet=True)
switch2.upload_file('labs_files/lab1/25sr.sh', '25sr.sh')
stdout, stderr = switch2.execute('chmod +x 25sr.sh && ./25sr.sh')
# Out:
# Obtaining JSON from switch...
# Done
# Control utility for runtime P4 table manipulation
# RuntimeCmd: Adding entry to lpm match table MyIngress.ipv4_lpm
# match key:           LPM-c0:a8:01:00/24
# action:              MyIngress.forward
# runtime data:        00:00:00:00:00:11	00:00
# Entry has been added with handle 0
# RuntimeCmd:
# Obtaining JSON from switch...
# Done
# Control utility for runtime P4 table manipulation
# RuntimeCmd: Adding entry to lpm match table MyIngress.ipv4_lpm
# match key:           LPM-c0:a8:07:00/24
# action:              MyIngress.forward
# runtime data:        00:00:00:00:00:14	00:01
# Entry has been added with handle 1
# RuntimeCmd:

# %%
server2_dest_ip = server2_ip.split('/')[0]
stdout, stderr = server1.execute(f'ping {server2_dest_ip} -c 3')
# Out:
# PING 192.168.2.10 (192.168.2.10) 56(84) bytes of data.
# 64 bytes from 192.168.2.10: icmp_seq=1 ttl=63 time=1.31 ms
# 64 bytes from 192.168.2.10: icmp_seq=2 ttl=63 time=0.503 ms
# 64 bytes from 192.168.2.10: icmp_seq=3 ttl=63 time=0.803 ms
#
# --- 192.168.2.10 ping statistics ---
# 3 packets transmitted, 3 received, 0% packet loss, time 2002ms
# rtt min/avg/max/mdev = 0.503/0.872/1.312/0.333 ms

# %%
cont_dest_ip = cont_ip.split('/')[0]
stdout, stderr = user2.execute(f'ping {cont_dest_ip} -c 3')
# Out:
# PING 192.168.5.10 (192.168.5.10) 56(84) bytes of data.
# 64 bytes from 192.168.5.10: icmp_seq=1 ttl=63 time=1.25 ms
# 64 bytes from 192.168.5.10: icmp_seq=2 ttl=63 time=0.575 ms
# 64 bytes from 192.168.5.10: icmp_seq=3 ttl=63 time=0.539 ms
#
# --- 192.168.5.10 ping statistics ---
# 3 packets transmitted, 3 received, 0% packet loss, time 2011ms
# rtt min/avg/max/mdev = 0.539/0.787/1.247/0.325 ms

# %%
user2_dest_ip = user2_ip.split('/')[0]
print(f'User2 dest ip = {user2_dest_ip}')
stdout, stderr = user1.execute(f'ping {user2_dest_ip} -c 3')
# Out:
# User2 dest ip = 192.168.4.10
# PING 192.168.4.10 (192.168.4.10) 56(84) bytes of data.
# 64 bytes from 192.168.4.10: icmp_seq=1 ttl=63 time=1.31 ms
# 64 bytes from 192.168.4.10: icmp_seq=2 ttl=63 time=0.518 ms
# 64 bytes from 192.168.4.10: icmp_seq=3 ttl=63 time=0.496 ms
#
# --- 192.168.4.10 ping statistics ---
# 3 packets transmitted, 3 received, 0% packet loss, time 2008ms
# rtt min/avg/max/mdev = 0.496/0.775/1.312/0.379 ms

# %%
switch.upload_file('scripts/simple_switch_hp.gz', '/home/ubuntu/simple_switch_hp.gz')
switch.execute('gzip -d simple_switch_hp.gz')
switch.execute('chmod +x /home/ubuntu/simple_switch_hp')
stdout, stderr = switch.execute(f'sudo pkill switch')

# %%
#2
switch2.upload_file('scripts/simple_switch_hp.gz', '/home/ubuntu/simple_switch_hp.gz')
switch2.execute('gzip -d simple_switch_hp.gz')
switch2.execute('chmod +x /home/ubuntu/simple_switch_hp')
stdout, stderr = switch2.execute(f'sudo pkill switch')

# %%
switch.upload_file('scripts/disable_offload.sh', 'disable_offload.sh')
stdout, stderr = switch.execute(f'sudo chmod +x ./disable_offload.sh && sudo ./disable_offload.sh {switch_iface1_name}', quiet=True)
stdout, stderr = switch.execute(f'sudo chmod +x ./disable_offload.sh && sudo ./disable_offload.sh {switch_iface2_name}', quiet=True)
stdout, stderr = switch.execute(f'sudo chmod +x ./disable_offload.sh && sudo ./disable_offload.sh {switch_iface3_name}', quiet=True)
stdout, stderr = switch.execute(f'sudo chmod +x ./disable_offload.sh && sudo ./disable_offload.sh {switch_iface4_name}', quiet=True)
stdout, stderr = switch.execute(f'sudo chmod +x ./disable_offload.sh && sudo ./disable_offload.sh {switch_iface5_name}', quiet=True)

# %%
#2
switch2.upload_file('scripts/disable_offload.sh', 'disable_offload.sh')
stdout, stderr = switch2.execute(f'sudo chmod +x ./disable_offload.sh && sudo ./disable_offload.sh {switch2_iface1_name}', quiet=True)
stdout, stderr = switch2.execute(f'sudo chmod +x ./disable_offload.sh && sudo ./disable_offload.sh {switch2_iface2_name}', quiet=True)

# %%
stdout, stderr = switch.execute(f'sudo /home/ubuntu/simple_switch_hp -i 0@{switch_iface1_name} -i 1@{switch_iface2_name} -i 2@{switch_iface3_name} -i 3@{switch_iface4_name} -i 4@{switch_iface5_name} main.json &')
stdout, stderr = switch.execute('chmod +x 5sr.sh && ./5sr.sh')
# Out:
# Calling target program-options parser
# Adding interface enp6s0 as port 0
# Adding interface enp9s0 as port 1
# Adding interface enp7s0 as port 2
# Adding interface enp10s0 as port 3
# Adding interface enp8s0 as port 4
# Obtaining JSON from switch...
# Done
# Control utility for runtime P4 table manipulation
# RuntimeCmd: Adding entry to lpm match table MyIngress.ipv4_lpm
# match key:           LPM-c0:a8:01:00/24
# action:              MyIngress.forward
# runtime data:        00:00:00:00:00:01	00:00
# Entry has been added with handle 0
# RuntimeCmd:
# Obtaining JSON from switch...
# Done
# Control utility for runtime P4 table manipulation
# RuntimeCmd: Adding entry to lpm match table MyIngress.ipv4_lpm
# match key:           LPM-c0:a8:02:00/24
# action:              MyIngress.forward
# runtime data:        00:00:00:00:00:04	00:01
# Entry has been added with handle 1
# RuntimeCmd:
# Obtaining JSON from switch...
# Done
# Control utility for runtime P4 table manipulation
# RuntimeCmd: Adding entry to lpm match table MyIngress.ipv4_lpm
# match key:           LPM-c0:a8:03:00/24
# action:              MyIngress.forward
# runtime data:        00:00:00:00:00:05	00:02
# Entry has been added with handle 2
# RuntimeCmd:
# Obtaining JSON from switch...
# Done
# Control utility for runtime P4 table manipulation
# RuntimeCmd: Adding entry to lpm match table MyIngress.ipv4_lpm
# match key:           LPM-c0:a8:04:00/24
# action:              MyIngress.forward
# runtime data:        00:00:00:00:00:08	00:03
# Entry has been added with handle 3
# RuntimeCmd:
# Obtaining JSON from switch...
# Done
# Control utility for runtime P4 table manipulation
# RuntimeCmd: Adding entry to lpm match table MyIngress.ipv4_lpm
# match key:           LPM-c0:a8:05:00/24
# action:              MyIngress.forward
# runtime data:        00:00:00:00:00:10	00:04
# Entry has been added with handle 4
# RuntimeCmd:

# %%
stdout, stderr = server1.execute(f'sudo apt-get update && sudo apt-get install -y iperf3', quiet=True)
stdout, stderr = server2.execute(f'sudo apt-get update && sudo apt-get install -y iperf3', quiet=True)
stdout, stderr = user1.execute(f'sudo apt-get update && sudo apt-get install -y iperf3', quiet=True)
stdout, stderr = user2.execute(f'sudo apt-get update && sudo apt-get install -y iperf3', quiet=True)
stdout, stderr = cont.execute(f'sudo apt-get update && sudo apt-get install -y iperf3', quiet=True)

# %%
#2
stdout, stderr = server3.execute(f'sudo apt-get update && sudo apt-get install -y iperf3', quiet=True)

# %%
user2.execute_thread('iperf3 -s')
# Out:
# <Future at 0x7f1148d8f430 state=running>

# %%
stdout, stderr = user1.execute('iperf3 -c 192.168.4.10 -P 5')
# Out:
#  iperf3: error - unable to connect to server: Connection refused

# %%
server1.upload_file('scripts/host_tune.sh', 'host_tune.sh')
stdout, stderr = server1.execute('chmod +x host_tune.sh && sudo ./host_tune.sh')
server2.upload_file('scripts/host_tune.sh', 'host_tune.sh')
stdout, stderr = server2.execute('chmod +x host_tune.sh && sudo ./host_tune.sh')
user1.upload_file('scripts/host_tune.sh', 'host_tune.sh')
stdout, stderr = user1.execute('chmod +x host_tune.sh && sudo ./host_tune.sh')
user2.upload_file('scripts/host_tune.sh', 'host_tune.sh')
stdout, stderr = server2.execute('chmod +x host_tune.sh && sudo ./host_tune.sh')
cont.upload_file('scripts/host_tune.sh', 'host_tune.sh')
stdout, stderr = cont.execute('chmod +x host_tune.sh && sudo ./host_tune.sh')
switch.upload_file('scripts/host_tune.sh', 'host_tune.sh')
stdout, stderr = switch.execute('chmod +x host_tune.sh && sudo ./host_tune.sh')
# Out:
# * Applying /etc/sysctl.d/10-console-messages.conf ...
# kernel.printk = 4 4 1 7
# * Applying /etc/sysctl.d/10-ipv6-privacy.conf ...
# net.ipv6.conf.all.use_tempaddr = 2
# net.ipv6.conf.default.use_tempaddr = 2
# * Applying /etc/sysctl.d/10-kernel-hardening.conf ...
# kernel.kptr_restrict = 1
# * Applying /etc/sysctl.d/10-link-restrictions.conf ...
# fs.protected_hardlinks = 1
# fs.protected_symlinks = 1
# * Applying /etc/sysctl.d/10-magic-sysrq.conf ...
# kernel.sysrq = 176
# * Applying /etc/sysctl.d/10-network-security.conf ...
# net.ipv4.conf.default.rp_filter = 2
# net.ipv4.conf.all.rp_filter = 2
# * Applying /etc/sysctl.d/10-ptrace.conf ...
# kernel.yama.ptrace_scope = 1
# * Applying /etc/sysctl.d/10-zeropage.conf ...
# vm.mmap_min_addr = 65536
# * Applying /usr/lib/sysctl.d/50-default.conf ...
# net.ipv4.conf.default.promote_secondaries = 1
#  sysctl: setting key "net.ipv4.conf.all.promote_secondaries": Invalid argument
#  net.ipv4.ping_group_range = 0 2147483647
# net.core.default_qdisc = fq_codel
# fs.protected_regular = 1
# fs.protected_fifos = 1
# * Applying /usr/lib/sysctl.d/50-pid-max.conf ...
# kernel.pid_max = 4194304
# * Applying /etc/sysctl.d/99-cloudimg-ipv6.conf ...
# net.ipv6.conf.all.use_tempaddr = 0
# net.ipv6.conf.default.use_tempaddr = 0
# * Applying /etc/sysctl.d/99-sysctl.conf ...
# net.core.rmem_max = 536870912
# net.core.wmem_max = 536870912
# net.ipv4.tcp_rmem = 4096 87380 536870912
# net.ipv4.tcp_wmem = 4096 65536 536870912
# net.ipv4.tcp_congestion_control = bbr
# net.ipv4.tcp_mtu_probing = 1
# net.core.default_qdisc = fq
# * Applying /usr/lib/sysctl.d/protect-links.conf ...
# fs.protected_fifos = 1
# fs.protected_hardlinks = 1
# fs.protected_regular = 2
# fs.protected_symlinks = 1
# * Applying /etc/sysctl.conf ...
# net.core.rmem_max = 536870912
# net.core.wmem_max = 536870912
# net.ipv4.tcp_rmem = 4096 87380 536870912
# net.ipv4.tcp_wmem = 4096 65536 536870912
# net.ipv4.tcp_congestion_control = bbr
# net.ipv4.tcp_mtu_probing = 1
# net.core.default_qdisc = fq
# * Applying /etc/sysctl.d/10-console-messages.conf ...
# kernel.printk = 4 4 1 7
# * Applying /etc/sysctl.d/10-ipv6-privacy.conf ...
# net.ipv6.conf.all.use_tempaddr = 2
# net.ipv6.conf.default.use_tempaddr = 2
# * Applying /etc/sysctl.d/10-kernel-hardening.conf ...
# kernel.kptr_restrict = 1
# * Applying /etc/sysctl.d/10-link-restrictions.conf ...
# fs.protected_hardlinks = 1
# fs.protected_symlinks = 1
# * Applying /etc/sysctl.d/10-magic-sysrq.conf ...
# kernel.sysrq = 176
# * Applying /etc/sysctl.d/10-network-security.conf ...
# net.ipv4.conf.default.rp_filter = 2
# net.ipv4.conf.all.rp_filter = 2
# * Applying /etc/sysctl.d/10-ptrace.conf ...
# kernel.yama.ptrace_scope = 1
# * Applying /etc/sysctl.d/10-zeropage.conf ...
# vm.mmap_min_addr = 65536
# * Applying /usr/lib/sysctl.d/50-default.conf ...
# net.ipv4.conf.default.promote_secondaries = 1
#  sysctl: setting key "net.ipv4.conf.all.promote_secondaries": Invalid argument
#  net.ipv4.ping_group_range = 0 2147483647
# net.core.default_qdisc = fq_codel
# fs.protected_regular = 1
# fs.protected_fifos = 1
# * Applying /usr/lib/sysctl.d/50-pid-max.conf ...
# kernel.pid_max = 4194304
# * Applying /etc/sysctl.d/99-cloudimg-ipv6.conf ...
# net.ipv6.conf.all.use_tempaddr = 0
# net.ipv6.conf.default.use_tempaddr = 0
# * Applying /etc/sysctl.d/99-sysctl.conf ...
# net.core.rmem_max = 536870912
# net.core.wmem_max = 536870912
# net.ipv4.tcp_rmem = 4096 87380 536870912
# net.ipv4.tcp_wmem = 4096 65536 536870912
# net.ipv4.tcp_congestion_control = bbr
# net.ipv4.tcp_mtu_probing = 1
# net.core.default_qdisc = fq
# * Applying /usr/lib/sysctl.d/protect-links.conf ...
# fs.protected_fifos = 1
# fs.protected_hardlinks = 1
# fs.protected_regular = 2
# fs.protected_symlinks = 1
# * Applying /etc/sysctl.conf ...
# net.core.rmem_max = 536870912
# net.core.wmem_max = 536870912
# net.ipv4.tcp_rmem = 4096 87380 536870912
# net.ipv4.tcp_wmem = 4096 65536 536870912
# net.ipv4.tcp_congestion_control = bbr
# net.ipv4.tcp_mtu_probing = 1
# net.core.default_qdisc = fq
# * Applying /etc/sysctl.d/10-console-messages.conf ...
# kernel.printk = 4 4 1 7
# * Applying /etc/sysctl.d/10-ipv6-privacy.conf ...
# net.ipv6.conf.all.use_tempaddr = 2
# net.ipv6.conf.default.use_tempaddr = 2
# * Applying /etc/sysctl.d/10-kernel-hardening.conf ...
# kernel.kptr_restrict = 1
# * Applying /etc/sysctl.d/10-link-restrictions.conf ...
# fs.protected_hardlinks = 1
# fs.protected_symlinks = 1
# * Applying /etc/sysctl.d/10-magic-sysrq.conf ...
# kernel.sysrq = 176
# * Applying /etc/sysctl.d/10-network-security.conf ...
# net.ipv4.conf.default.rp_filter = 2
# net.ipv4.conf.all.rp_filter = 2
# * Applying /etc/sysctl.d/10-ptrace.conf ...
# kernel.yama.ptrace_scope = 1
# * Applying /etc/sysctl.d/10-zeropage.conf ...
# vm.mmap_min_addr = 65536
# * Applying /usr/lib/sysctl.d/50-default.conf ...
# net.ipv4.conf.default.promote_secondaries = 1
#  sysctl: setting key "net.ipv4.conf.all.promote_secondaries": Invalid argument
#  net.ipv4.ping_group_range = 0 2147483647
# net.core.default_qdisc = fq_codel
# fs.protected_regular = 1
# fs.protected_fifos = 1
# * Applying /usr/lib/sysctl.d/50-pid-max.conf ...
# kernel.pid_max = 4194304
# * Applying /etc/sysctl.d/99-cloudimg-ipv6.conf ...
# net.ipv6.conf.all.use_tempaddr = 0
# net.ipv6.conf.default.use_tempaddr = 0
# * Applying /etc/sysctl.d/99-sysctl.conf ...
# net.core.rmem_max = 536870912
# net.core.wmem_max = 536870912
# net.ipv4.tcp_rmem = 4096 87380 536870912
# net.ipv4.tcp_wmem = 4096 65536 536870912
# net.ipv4.tcp_congestion_control = bbr
# net.ipv4.tcp_mtu_probing = 1
# net.core.default_qdisc = fq
# * Applying /usr/lib/sysctl.d/protect-links.conf ...
# fs.protected_fifos = 1
# fs.protected_hardlinks = 1
# fs.protected_regular = 2
# fs.protected_symlinks = 1
# * Applying /etc/sysctl.conf ...
# net.core.rmem_max = 536870912
# net.core.wmem_max = 536870912
# net.ipv4.tcp_rmem = 4096 87380 536870912
# net.ipv4.tcp_wmem = 4096 65536 536870912
# net.ipv4.tcp_congestion_control = bbr
# net.ipv4.tcp_mtu_probing = 1
# net.core.default_qdisc = fq
# * Applying /etc/sysctl.d/10-console-messages.conf ...
# kernel.printk = 4 4 1 7
# * Applying /etc/sysctl.d/10-ipv6-privacy.conf ...
# net.ipv6.conf.all.use_tempaddr = 2
# net.ipv6.conf.default.use_tempaddr = 2
# * Applying /etc/sysctl.d/10-kernel-hardening.conf ...
# kernel.kptr_restrict = 1
# * Applying /etc/sysctl.d/10-link-restrictions.conf ...
# fs.protected_hardlinks = 1
# fs.protected_symlinks = 1
# * Applying /etc/sysctl.d/10-magic-sysrq.conf ...
# kernel.sysrq = 176
# * Applying /etc/sysctl.d/10-network-security.conf ...
# net.ipv4.conf.default.rp_filter = 2
# net.ipv4.conf.all.rp_filter = 2
# * Applying /etc/sysctl.d/10-ptrace.conf ...
# kernel.yama.ptrace_scope = 1
# * Applying /etc/sysctl.d/10-zeropage.conf ...
# vm.mmap_min_addr = 65536
# * Applying /usr/lib/sysctl.d/50-default.conf ...
# net.ipv4.conf.default.promote_secondaries = 1
# net.ipv4.ping_group_range = 0 2147483647
# net.core.default_qdisc = fq_codel
# fs.protected_regular = 1
# fs.protected_fifos = 1
# * Applying /usr/lib/sysctl.d/50-pid-max.conf ...
# kernel.pid_max = 4194304
# * Applying /etc/sysctl.d/99-cloudimg-ipv6.conf ...
# net.ipv6.conf.all.use_tempaddr = 0
# net.ipv6.conf.default.use_tempaddr = 0
# * Applying /etc/sysctl.d/99-sysctl.conf ...
# net.core.rmem_max = 536870912
# net.core.wmem_max = 536870912
# net.ipv4.tcp_rmem = 4096 87380 536870912
# net.ipv4.tcp_wmem = 4096 65536 536870912
# net.ipv4.tcp_congestion_control = bbr
# net.ipv4.tcp_mtu_probing = 1
# net.core.default_qdisc = fq
# net.core.rmem_max = 536870912
# net.core.wmem_max = 536870912
# net.ipv4.tcp_rmem = 4096 87380 536870912
# net.ipv4.tcp_wmem = 4096 65536 536870912
# net.ipv4.tcp_congestion_control = bbr
# net.ipv4.tcp_mtu_probing = 1
# net.core.default_qdisc = fq
# * Applying /usr/lib/sysctl.d/protect-links.conf ...
# fs.protected_fifos = 1
# fs.protected_hardlinks = 1
# fs.protected_regular = 2
# fs.protected_symlinks = 1
# * Applying /etc/sysctl.conf ...
# net.core.rmem_max = 536870912
# net.core.wmem_max = 536870912
# net.ipv4.tcp_rmem = 4096 87380 536870912
# net.ipv4.tcp_wmem = 4096 65536 536870912
# net.ipv4.tcp_congestion_control = bbr
# net.ipv4.tcp_mtu_probing = 1
# net.core.default_qdisc = fq
# net.core.rmem_max = 536870912
# net.core.wmem_max = 536870912
# net.ipv4.tcp_rmem = 4096 87380 536870912
# net.ipv4.tcp_wmem = 4096 65536 536870912
# net.ipv4.tcp_congestion_control = bbr
# net.ipv4.tcp_mtu_probing = 1
# net.core.default_qdisc = fq
#  sysctl: setting key "net.ipv4.conf.all.promote_secondaries": Invalid argument
#  * Applying /etc/sysctl.d/10-console-messages.conf ...
# kernel.printk = 4 4 1 7
# * Applying /etc/sysctl.d/10-ipv6-privacy.conf ...
# net.ipv6.conf.all.use_tempaddr = 2
# net.ipv6.conf.default.use_tempaddr = 2
# * Applying /etc/sysctl.d/10-kernel-hardening.conf ...
# kernel.kptr_restrict = 1
# * Applying /etc/sysctl.d/10-link-restrictions.conf ...
# fs.protected_hardlinks = 1
# fs.protected_symlinks = 1
# * Applying /etc/sysctl.d/10-magic-sysrq.conf ...
# kernel.sysrq = 176
# * Applying /etc/sysctl.d/10-network-security.conf ...
# net.ipv4.conf.default.rp_filter = 2
# net.ipv4.conf.all.rp_filter = 2
# * Applying /etc/sysctl.d/10-ptrace.conf ...
# kernel.yama.ptrace_scope = 1
# * Applying /etc/sysctl.d/10-zeropage.conf ...
# vm.mmap_min_addr = 65536
# * Applying /usr/lib/sysctl.d/50-default.conf ...
# net.ipv4.conf.default.promote_secondaries = 1
#  sysctl: setting key "net.ipv4.conf.all.promote_secondaries": Invalid argument
#  net.ipv4.ping_group_range = 0 2147483647
# net.core.default_qdisc = fq_codel
# fs.protected_regular = 1
# fs.protected_fifos = 1
# * Applying /usr/lib/sysctl.d/50-pid-max.conf ...
# kernel.pid_max = 4194304
# * Applying /etc/sysctl.d/99-cloudimg-ipv6.conf ...
# net.ipv6.conf.all.use_tempaddr = 0
# net.ipv6.conf.default.use_tempaddr = 0
# * Applying /etc/sysctl.d/99-sysctl.conf ...
# net.core.rmem_max = 536870912
# net.core.wmem_max = 536870912
# net.ipv4.tcp_rmem = 4096 87380 536870912
# net.ipv4.tcp_wmem = 4096 65536 536870912
# net.ipv4.tcp_congestion_control = bbr
# net.ipv4.tcp_mtu_probing = 1
# net.core.default_qdisc = fq
# * Applying /usr/lib/sysctl.d/protect-links.conf ...
# fs.protected_fifos = 1
# fs.protected_hardlinks = 1
# fs.protected_regular = 2
# fs.protected_symlinks = 1
# * Applying /etc/sysctl.conf ...
# net.core.rmem_max = 536870912
# net.core.wmem_max = 536870912
# net.ipv4.tcp_rmem = 4096 87380 536870912
# net.ipv4.tcp_wmem = 4096 65536 536870912
# net.ipv4.tcp_congestion_control = bbr
# net.ipv4.tcp_mtu_probing = 1
# net.core.default_qdisc = fq
# * Applying /etc/sysctl.d/10-console-messages.conf ...
# kernel.printk = 4 4 1 7
# * Applying /etc/sysctl.d/10-ipv6-privacy.conf ...
# net.ipv6.conf.all.use_tempaddr = 2
# net.ipv6.conf.default.use_tempaddr = 2
# * Applying /etc/sysctl.d/10-kernel-hardening.conf ...
# kernel.kptr_restrict = 1
# * Applying /etc/sysctl.d/10-link-restrictions.conf ...
# fs.protected_hardlinks = 1
# fs.protected_symlinks = 1
# * Applying /etc/sysctl.d/10-magic-sysrq.conf ...
# kernel.sysrq = 176
# * Applying /etc/sysctl.d/10-network-security.conf ...
# net.ipv4.conf.default.rp_filter = 2
# net.ipv4.conf.all.rp_filter = 2
# * Applying /etc/sysctl.d/10-ptrace.conf ...
# kernel.yama.ptrace_scope = 1
# * Applying /etc/sysctl.d/10-zeropage.conf ...
# vm.mmap_min_addr = 65536
# * Applying /usr/lib/sysctl.d/50-default.conf ...
# net.ipv4.conf.default.promote_secondaries = 1
#  sysctl: setting key "net.ipv4.conf.all.promote_secondaries": Invalid argument
#  net.ipv4.ping_group_range = 0 2147483647
# net.core.default_qdisc = fq_codel
# fs.protected_regular = 1
# fs.protected_fifos = 1
# * Applying /usr/lib/sysctl.d/50-pid-max.conf ...
# kernel.pid_max = 4194304
# * Applying /etc/sysctl.d/99-cloudimg-ipv6.conf ...
# net.ipv6.conf.all.use_tempaddr = 0
# net.ipv6.conf.default.use_tempaddr = 0
# * Applying /etc/sysctl.d/99-sysctl.conf ...
# net.core.rmem_max = 536870912
# net.core.wmem_max = 536870912
# net.ipv4.tcp_rmem = 4096 87380 536870912
# net.ipv4.tcp_wmem = 4096 65536 536870912
# net.ipv4.tcp_congestion_control = bbr
# net.ipv4.tcp_mtu_probing = 1
# net.core.default_qdisc = fq
# * Applying /usr/lib/sysctl.d/protect-links.conf ...
# fs.protected_fifos = 1
# fs.protected_hardlinks = 1
# fs.protected_regular = 2
# fs.protected_symlinks = 1
# * Applying /etc/sysctl.conf ...
# net.core.rmem_max = 536870912
# net.core.wmem_max = 536870912
# net.ipv4.tcp_rmem = 4096 87380 536870912
# net.ipv4.tcp_wmem = 4096 65536 536870912
# net.ipv4.tcp_congestion_control = bbr
# net.ipv4.tcp_mtu_probing = 1
# net.core.default_qdisc = fq

# %%
#2
server3.upload_file('scripts/host_tune.sh', 'host_tune.sh')
stdout, stderr = server3.execute('chmod +x host_tune.sh && sudo ./host_tune.sh')
switch2.upload_file('scripts/host_tune.sh', 'host_tune.sh')
stdout, stderr = switch2.execute('chmod +x host_tune.sh && sudo ./host_tune.sh')
# Out:
# * Applying /etc/sysctl.d/10-console-messages.conf ...
# kernel.printk = 4 4 1 7
# * Applying /etc/sysctl.d/10-ipv6-privacy.conf ...
# net.ipv6.conf.all.use_tempaddr = 2
# net.ipv6.conf.default.use_tempaddr = 2
# * Applying /etc/sysctl.d/10-kernel-hardening.conf ...
# kernel.kptr_restrict = 1
# * Applying /etc/sysctl.d/10-link-restrictions.conf ...
# fs.protected_hardlinks = 1
# fs.protected_symlinks = 1
# * Applying /etc/sysctl.d/10-magic-sysrq.conf ...
# kernel.sysrq = 176
# * Applying /etc/sysctl.d/10-network-security.conf ...
# net.ipv4.conf.default.rp_filter = 2
# net.ipv4.conf.all.rp_filter = 2
# * Applying /etc/sysctl.d/10-ptrace.conf ...
# kernel.yama.ptrace_scope = 1
# * Applying /etc/sysctl.d/10-zeropage.conf ...
# vm.mmap_min_addr = 65536
# * Applying /usr/lib/sysctl.d/50-default.conf ...
# net.ipv4.conf.default.promote_secondaries = 1
#  sysctl: setting key "net.ipv4.conf.all.promote_secondaries": Invalid argument
#  net.ipv4.ping_group_range = 0 2147483647
# net.core.default_qdisc = fq_codel
# fs.protected_regular = 1
# fs.protected_fifos = 1
# * Applying /usr/lib/sysctl.d/50-pid-max.conf ...
# kernel.pid_max = 4194304
# * Applying /etc/sysctl.d/99-cloudimg-ipv6.conf ...
# net.ipv6.conf.all.use_tempaddr = 0
# net.ipv6.conf.default.use_tempaddr = 0
# * Applying /etc/sysctl.d/99-sysctl.conf ...
# net.core.rmem_max = 536870912
# net.core.wmem_max = 536870912
# net.ipv4.tcp_rmem = 4096 87380 536870912
# net.ipv4.tcp_wmem = 4096 65536 536870912
# net.ipv4.tcp_congestion_control = bbr
# net.ipv4.tcp_mtu_probing = 1
# net.core.default_qdisc = fq
# * Applying /usr/lib/sysctl.d/protect-links.conf ...
# fs.protected_fifos = 1
# fs.protected_hardlinks = 1
# fs.protected_regular = 2
# fs.protected_symlinks = 1
# * Applying /etc/sysctl.conf ...
# net.core.rmem_max = 536870912
# net.core.wmem_max = 536870912
# net.ipv4.tcp_rmem = 4096 87380 536870912
# net.ipv4.tcp_wmem = 4096 65536 536870912
# net.ipv4.tcp_congestion_control = bbr
# net.ipv4.tcp_mtu_probing = 1
# net.core.default_qdisc = fq
# * Applying /etc/sysctl.d/10-console-messages.conf ...
# kernel.printk = 4 4 1 7
# * Applying /etc/sysctl.d/10-ipv6-privacy.conf ...
# net.ipv6.conf.all.use_tempaddr = 2
# net.ipv6.conf.default.use_tempaddr = 2
# * Applying /etc/sysctl.d/10-kernel-hardening.conf ...
# kernel.kptr_restrict = 1
# * Applying /etc/sysctl.d/10-link-restrictions.conf ...
# fs.protected_hardlinks = 1
# fs.protected_symlinks = 1
# * Applying /etc/sysctl.d/10-magic-sysrq.conf ...
# kernel.sysrq = 176
# * Applying /etc/sysctl.d/10-network-security.conf ...
# net.ipv4.conf.default.rp_filter = 2
# net.ipv4.conf.all.rp_filter = 2
# * Applying /etc/sysctl.d/10-ptrace.conf ...
# kernel.yama.ptrace_scope = 1
# * Applying /etc/sysctl.d/10-zeropage.conf ...
# vm.mmap_min_addr = 65536
# * Applying /usr/lib/sysctl.d/50-default.conf ...
# net.ipv4.conf.default.promote_secondaries = 1
#  sysctl: setting key "net.ipv4.conf.all.promote_secondaries": Invalid argument
#  net.ipv4.ping_group_range = 0 2147483647
# net.core.default_qdisc = fq_codel
# fs.protected_regular = 1
# fs.protected_fifos = 1
# * Applying /usr/lib/sysctl.d/50-pid-max.conf ...
# kernel.pid_max = 4194304
# * Applying /etc/sysctl.d/99-cloudimg-ipv6.conf ...
# net.ipv6.conf.all.use_tempaddr = 0
# net.ipv6.conf.default.use_tempaddr = 0
# * Applying /etc/sysctl.d/99-sysctl.conf ...
# net.core.rmem_max = 536870912
# net.core.wmem_max = 536870912
# net.ipv4.tcp_rmem = 4096 87380 536870912
# net.ipv4.tcp_wmem = 4096 65536 536870912
# net.ipv4.tcp_congestion_control = bbr
# net.ipv4.tcp_mtu_probing = 1
# net.core.default_qdisc = fq
# * Applying /usr/lib/sysctl.d/protect-links.conf ...
# fs.protected_fifos = 1
# fs.protected_hardlinks = 1
# fs.protected_regular = 2
# fs.protected_symlinks = 1
# * Applying /etc/sysctl.conf ...
# net.core.rmem_max = 536870912
# net.core.wmem_max = 536870912
# net.ipv4.tcp_rmem = 4096 87380 536870912
# net.ipv4.tcp_wmem = 4096 65536 536870912
# net.ipv4.tcp_congestion_control = bbr
# net.ipv4.tcp_mtu_probing = 1
# net.core.default_qdisc = fq

# %%
user1_dest_ip = user1_ip.split('/')[0]
print(f'User1 dest ip = {user1_dest_ip}')
stdout, stderr = server1.execute(f'ping {user1_dest_ip} -c 3')
# Out:
# User1 dest ip = 192.168.3.10
# PING 192.168.3.10 (192.168.3.10) 56(84) bytes of data.
# 64 bytes from 192.168.3.10: icmp_seq=1 ttl=63 time=2.60 ms
# 64 bytes from 192.168.3.10: icmp_seq=2 ttl=63 time=0.384 ms
# 64 bytes from 192.168.3.10: icmp_seq=3 ttl=63 time=0.570 ms
#
# --- 192.168.3.10 ping statistics ---
# 3 packets transmitted, 3 received, 0% packet loss, time 2015ms
# rtt min/avg/max/mdev = 0.384/1.185/2.602/1.004 ms

# %%
#2
server3_dest_ip = server3_ip.split('/')[0]
print(f'Server3 dest ip = {server3_dest_ip}')
stdout, stderr = server1.execute(f'ping {server3_dest_ip} -c 3')
# Out:
# Server3 dest ip = 192.168.7.10
# PING 192.168.7.10 (192.168.7.10) 56(84) bytes of data.
#
# --- 192.168.7.10 ping statistics ---
# 3 packets transmitted, 0 received, 100% packet loss, time 2050ms
